# %%
#A loop is a block of code that executes a code a number of times or until some condition is met. 
#Python has two kinds of loops; (While loops and For loops).

# %%
x = 1
while x < 5:
    print(x)
    x = x + 1
    #If you run a program that enters an infinite loop, you can force Python to quit by pressing Ctrl + C
# Out:
# 1
# 2
# 3
# 4

# %%
num = float(input("enter a positive number : "))
while num <= 0:
    print("That's not a positive number amore!")

# %%
#The for statement begins with the for keyword, followed by amembership expression, and ends in a colon (:).
# Each line is indented four spaces.
for letter in "Racheal":
    print(letter)
# Out:
# R
# a
# c
# h
# e
# a
# l

# %%
for n in range(3):
    print("racheal")
# Out:
# racheal
# racheal
# racheal

# %%
for n in range(12, 18):
    print(n * n)
# Out:
# 144
# 169
# 196
# 225
# 256
# 289

# %%
amount = float(input("Enter an amount: "))
for num_people in range(2, 6):
 print(f"{num_people} people: £{amount / num_people:,.2f} each")
# Out:
# 2 people: £250.00 each
# 3 people: £166.67 each
# 4 people: £125.00 each
# 5 people: £100.00 each

# %%
for x in range(2, 5):
    for y in range(4, 6):
        print(f"x = {x} and y = {y}")
# Out:
# x = 2 and y = 4
# x = 2 and y = 5
# x = 3 and y = 4
# x = 3 and y = 5
# x = 4 and y = 4
# x = 4 and y = 5

# %%
for z in range (2, 11):
    print (z)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10

# %%
for y in range (2, 20, 2): # range(2 , 20, 2) 2 and 20 rep the range while the last 2 mean count in 2 step (even)
    print (y)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %%
for x in range (1, 12, 2):    #odd counting
    print (x)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11

# %%
def doubles (num):
    return num * 2
    

num = 2
for x in range (4):
    num = doubles(num)
    print(num)
# Out:
# 4
# 8
# 16
# 32

# %%
#invest.py
def invest(amount, rate, years):

    current = amount
    for year in range(1, years + 1):
        current = current * (1 + rate)
        print(f"year {year}: £{current:.2f}")

principal = float(input("Enter the initial investment amount: £"))
annual_rate = float(input("Enter the annual rate of return (as decimal): "))
num_years = int(input("Enter the number of years: "))

print("Investment growth over time:")
invest(principal, annual_rate, num_years)
# Out:
# Investment growth over time:
# year 1: £144.00
# year 2: £172.80
# year 3: £207.36
# year 4: £248.83
