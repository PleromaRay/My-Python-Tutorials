# %%
#a > b (a greater than b)
# a < b (a less than b)
# a >= b (a greater than or equal to b)
# a <= b (a less than or equal to b)
# a != b (a not equal to b)
# a == b (a equal to b)

# %%
1 ==1
# Out:
# True

# %%
20 < 18
# Out:
# False

# %%
"ray" > "roy" #alphabetical order
# Out:
# False

# %%
123 == "123"
# Out:
# False

# %%
#True and True True
#True and False False
#False and True False
#False and False False
3 > 2 and 4 < 5
# Out:
# True

# %%
3 < 2 and 4 < 5
# Out:
# False

# %%
grade = 95
if grade >= 70:
    print("You passed the class!")
    print("Thank you for attending.")
# Out:
# You passed the class!
# Thank you for attending.

# %%
grade = 40
if grade >= 70:
    print("You passed the class!")

if grade < 70:
    print("You did not pass the class :")
    print("Thank you for attending.")
# Out:
# You did not pass the class :
# Thank you for attending.

# %%
grade = 40
if grade >= 70:
    print("You passed the class!")
else:
    print("You did not pass the class :")
    print("Thank you for attending.")
# Out:
# You did not pass the class :
# Thank you for attending.

# %%
grade = 90 # 1

if grade >= 90: # 2
    print("You passed the class with an A.")

elif grade >= 80: # 3
    print("You passed the class with a B.")

elif grade >= 70: # 4
    print("You passed the class with a C.")

else: # 5
    print("You did not pass the class :")
    print("Thanks for attending.") # 6
# Out:
# You passed the class with an A.

# %%
# Prompt the user to enter a word
word = input("Enter a word: ")

# Get the length of the word
length = len(word)

# Compare the length to 5 and print the appropriate message
if length > 5:
    print("The word is longer than 5 characters.")
elif length < 5:
    print("The word is shorter than 5 characters.")
else:
    print("The word is exactly 5 characters long.")
# Out:
# The word is longer than 5 characters.

# %%
# Display the challenge message

print("I'm thinking of a number between 1 and 10. Guess which one.")

# Get the user's guess
guess = int(input("Your guess: "))

# Check if the guess is the secret number (which is 3)
if guess == 3:
    print("You win! Hurray")
else:
    print("You lose. Booh!")
    print("The number I was thinking of was 3.")
# Out:
# I'm thinking of a number between 1 and 10. Guess which one.
# You lose. Booh!
# The number I was thinking of was 3.
